# %%
# !pip install bs4
# !pip install requests
# Out:
# ...
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1271 sha256=2d949e0a8526c539e18d2d040a88e1ab5fd81cec540adaaac0a120b3161b83e4
#   Stored in directory: c:\users\dell\appdata\local\pip\cache\wheels\73\2b\cb\099980278a0c9a3e57ff1a89875ec07bfa0b6fcbebb9a8cad3
# Successfully built bs4
# ...

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %% [markdown]
# # 1) Write a python program to display all the header tags from wikipedia.org.

# %%
page=requests.get('https://en.wikipedia.org/wiki/Main_Page#')

# %%
page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Wikipedia, the free encyclopedia</title>
# ...

# %%
header=[]
for i in soup.find_all(['h1','h2','h3',]):
    header.append(i.text)

# %%
print(*header,sep='-')
# Out:
# Main Page-Welcome to Wikipedia-From today's featured article-Did you know ...-In the news-On this day-From today's featured list-Today's featured picture-Other areas of Wikipedia-Wikipedia's sister projects-Wikipedia languages-Navigation menu-
# Personal tools
# -
# Namespaces
# -
# Views
# -
# Search
# -
# Navigation
# -
# Contribute
# -
# Tools
# -
# Print/export
# -
# In other projects
# -
# Languages

# %% [markdown]
# # Write a python program to display IMDB’s Top rated 100 movies’ data (i.e. name, rating, year of release

# %%
page=requests.get('https://www.imdb.com/list/ls091520106/')
soup=BeautifulSoup(page.content)
soup

# %%
x=soup.find_all('div',class_="lister-item-content")
x

# %%
a=[]
b=[]
c=[]

# %%
for i in x:
    name=i.h3.a.text
    name
    a.append(name)

# %%
for i in soup.find_all('div',class_="ipl-rating-widget"):
    b.append(i.text.replace('\n',''))

# %%
for i in soup.find_all('span',class_="lister-item-year text-muted unbold"):
    c.append(i.text)

# %%
df=pd.DataFrame({'Movie_Name':a,'IMDB Rating':b,'Year_Of_Release':c})
df
# Out:
#                            Movie_Name  \
# 0                     Ship of Theseus
# 1                              Iruvar
# 2                     Kaagaz Ke Phool
# 3   Lagaan: Once Upon a Time in India
# 4                     Pather Panchali
# ..                                ...
# 95                        Apur Sansar
# 96                        Kanchivaram
# 97                    Monsoon Wedding
# 98                              Black
# 99                            Deewaar
#
#                                           IMDB Rating Year_Of_Release
# 0   80Rate 1Rate2Rate3Rate4Rate5Rate6Rate7Rate8Rat...          (2012)
# 1   8.40Rate 1Rate2Rate3Rate4Rate5Rate6Rate7Rate8R...          (1997)
# 2   7.80Rate 1Rate2Rate3Rate4Rate5Rate6Rate7Rate8R...          (1959)
# 3   8.10Rate 1Rate2Rate3Rate4Rate5Rate6Rate7Rate8R...          (2001)
# 4   8.30Rate 1Rate2Rate3Rate4Rate5Rate6Rate7Rate8R...          (1955)
# ..                                                ...             ...
# ...

# %% [markdown]
# # 3) Write a python program to display IMDB’s Top rated 100 Indian movies’ data

# %%
page=requests.get('https://www.imdb.com/list/ls056092300/')
soup=BeautifulSoup(page.content)
soup
x=soup.find_all('div',class_="lister-item mode-detail")
x
# Out:
# [<div class="lister-item mode-detail">
#  <div class="lister-item-image ribbonize" data-tconst="tt1773764">
#  <a href="/title/tt1773764/"> <img alt="Ship of Theseus" class="loadlate" data-tconst="tt1773764" height="209" loadlate="https://m.media-amazon.com/images/M/MV5BMTU5Njc1NjkxMl5BMl5BanBnXkFtZTgwNTkzNTQwMDE@._V1_UY209_CR2,0,140,209_AL_.jpg" src="https://m.media-amazon.com/images/S/sash/4FyxwxECzL-U1J8.png" width="140"/>
#  </a> </div>
#  <div class="lister-item-content">
#  <h3 class="lister-item-header">
#  <span class="lister-item-index unbold text-primary">1.</span>
#  <a href="/title/tt1773764/">Ship of Theseus</a>
#  <span class="lister-item-year text-muted unbold">(2012)</span>
#  </h3>
#  <p class="text-muted text-small">
#  <span class="certificate">UA</span>
#  <span class="ghost">|</span>
#  <span class="runtime">139 min</span>
#  <span class="ghost">|</span>
#  <span class="genre">
#  Drama            </span>
#  </p>
#  <div class="ipl-rating-widget">
# ...

# %%
a=[]
b=[]
c=[]

# %%
for i in x:

    name=i.h3.a.text
    name
    a.append(name)

# %%
z=soup.find('div',class_="ipl-rating-widget").text.replace('\n','')
z
# Out:
# '80Rate 1Rate2Rate3Rate4Rate5Rate6Rate7Rate8Rate9Rate10Rate0Error: please try again.'

# %%
for i in soup.find_all('div',class_="ipl-rating-widget"):
    b.append(i.text.replace('\n',''))

# %%
for i in soup.findAll('span',class_="lister-item-year text-muted unbold"):
    c.append(i.text)
    c

# %%
df=pd.DataFrame({'top_100_ind_mov':a,'Movie_Rating':b,'Year_Of_Release':c})

# %%
df
# Out:
#                       top_100_ind_mov  \
# 0                     Ship of Theseus
# 1                              Iruvar
# 2                     Kaagaz Ke Phool
# 3   Lagaan: Once Upon a Time in India
# 4                     Pather Panchali
# ..                                ...
# 95                        Apur Sansar
# 96                        Kanchivaram
# 97                    Monsoon Wedding
# 98                              Black
# 99                            Deewaar
#
#                                          Movie_Rating Year_Of_Release
# 0   80Rate 1Rate2Rate3Rate4Rate5Rate6Rate7Rate8Rat...          (2012)
# 1   8.40Rate 1Rate2Rate3Rate4Rate5Rate6Rate7Rate8R...          (1997)
# 2   7.80Rate 1Rate2Rate3Rate4Rate5Rate6Rate7Rate8R...          (1959)
# 3   8.10Rate 1Rate2Rate3Rate4Rate5Rate6Rate7Rate8R...          (2001)
# 4   8.30Rate 1Rate2Rate3Rate4Rate5Rate6Rate7Rate8R...          (1955)
# ..                                                ...             ...
# ...

# %% [markdown]
# # 4) Write s python program to display list of respected former presidents of India(i.e. Name , Term of office)
# # https://presidentofindia.nic.in/former-presidents.ht

# %%
page=requests.get('https://presidentofindia.nic.in/former-presidents.htm')
page
soup=BeautifulSoup(page.content)
soup
x=soup.find_all('div',class_="presidentListing")
x

# %%
a1=[]
a2=[]

# %%
for i in soup.find_all('div',class_="presidentListing"):
    a1.append(i.text)

# %%
for i in x:
    i.p.text
    a2.append(i)

# %%
df=pd.DataFrame({'Name':a1,'Term Of Offic':a2})
df

# %% [markdown]
# # 5) Write a python program to scrape cricket rankings from icc-cricket.com. You have to scrape:

# %%
#a) Top 10 ODI teams in men’s cricket along with the records for matches, points and rating.

# %%
page=requests.get('https://www.icc-cricket.com/rankings/mens/team-rankings/odi')

soup=BeautifulSoup(page.content)
soup

k=soup.find_all('tr',class_="table-body")
k
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6220/1627688011.py in <module>
# ----> 1 page=requests.get('https://www.icc-cricket.com/rankings/mens/team-rankings/odi')
#       2 soup=BeautifulSoup(page.content)
#       3 soup
#
# NameError: name 'requests' is not defined

# %%
x=[]
for i in soup.find_all('span',class_="u-hide-phablet"):
    x.append(i.text)

# %%
x_=x[0:10]

# %%
y=[]
for i in soup.findAll('td', class_="table-body__cell u-center-text"):
    y.append(i.text)

# %%
y_=[]
for i in range (0,len(y),2):
    print(y[i])
    y_.append(y[i])

# %%
u=y_[0:9]
len(u)

# %%
v=[]
for j in range(1,len(y),2):
    print(y[j])
    v.append(y[j])

# %%
v_=v[0:9]
v_
m=soup.find('td',class_="rankings-block__banner--matches").text
n_=soup.find('td',class_="rankings-block__banner--points").text
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6220/3092480481.py in <module>
# ----> 1 v_=v[0:9]
#       2 v_
#       3 m=soup.find('td',class_="rankings-block__banner--matches").text
#       4 n_=soup.find('td',class_="rankings-block__banner--points").text
#
# NameError: name 'v' is not defined

# %%
l=y_.insert(0,m)
o=v_.insert(0,n_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6220/2830914502.py in <module>
# ----> 1 l=y_.insert(0,m)
#       2 o=v_.insert(0,n_)
#
# NameError: name 'y_' is not defined

# %%
df=pd.DataFrame({'Matches':x_,'points':o,'Rank':l})

# %%
#b) Top 10 ODI Batsmen along with the records of their team and rating.

# %%
page=requests.get('https://www.icc-cricket.com/rankings/mens/player-rankings/odi')
page
soup=BeautifulSoup(page.content)

# %%
x=[]
for i in soup.find_all('tr',class_="table-body"):
    x.append(i)

# %%
a=[]
for i in soup.find_all('td',class_="table-body__cell name"):
    a.append(i.text.replace('\n',''))

# %%
A=a[0:9]

# %%
a_=soup.find('div',class_="rankings-block__banner--name")
A_=a_.text

# %%
Aa=A.append(A_)

# %%
b=[]
for i in soup.find_all('span',class_="table-body__logo-text"):
    b.append(i.text)

# %%
B=b[0:10]
b_=soup.find('div',class_="rankings-block__banner--nationality")

# %%
B_=b_.text.replace('\n','').replace('892','')

# %%
Bb=B.append(B_)

# %%
c=[]
for i in soup.find_all('td',class_="table-body__cell u-text-right rating"):
    c.append(i.text)

# %%
C=c[0:10]

# %%
c_=soup.find('div',class_="rankings-block__banner--rating")

# %%
C_=b_.text

# %%
Cc=c.append(C_)
df=pd.DataFrame({'Player Name':[Aa],'Nationality':[Bb],'Rating':[Cc]})
df

# %%
#c) Top 10 ODI bowlers along with the records of their team and rating.

# %%
page=requests.get('https://www.icc-cricket.com/rankings/mens/player-rankings/odi')
page
soup=BeautifulSoup(page.content)

# %%
x=[]
for i in soup.find_all('tr',class_="table-body"):
    x.append(i)

# %%
a=[]
for i in soup.find_all('td',class_="table-body__cell name"):
    a.append(i.text.replace('\n',''))

# %%
a.=a_[1]

# %%
b=[]
for i in soup.find_all('span',class_="table-body__logo-text"):
    b.append(i.text)

# %%
B=b[9:19]

# %%
b_=[]
for i in soup.findAll('div',class_="rankings-block__banner--nationality"):
    b_.append(i.text.replace('\n','').replace('726',''))

# %%
b_[1]

# %%
c=[]
for i in soup.find_all('td',class_="table-body__cell u-text-right rating"):
    c.append(i.text)

# %%
C=c[0:10]

# %%
c_=[]
for i in soup.findAll('div',class_="rankings-block__banner--rat"):
    c.append(i.text)

# %%
c_

# %%
Cc=c.append(C_)

# %%
df=pd.DataFrame({'Player Name':[Aa],'Nationality':[Bb],'Rating':[Cc]})
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6220/389894852.py in <module>
# ----> 1 df=pd.DataFrame({'Player Name':[Aa],'Nationality':[Bb],'Rating':[Cc]})
#       2 df
#
# NameError: name 'pd' is not defined

# %% [markdown]
# # 5) Write a python program to scrape cricket rankings from icc-cricket.com. You have to scrape:

# %%
#a) Top 10 ODI teams in men’s cricket along with the records for matches, points and rating.

# %%
page=requests.get('https://www.icc-cricket.com/rankings/womens/team-rankings/odi')
page
soup=BeautifulSoup(page.content)
soup.text
k=soup.find_all('tr',class_="table-body")
k
x=[]
for i in soup.find_all('span',class_="u-hide-phablet"):
    x.append(i.text)

# %%
x_=x[0:10]
x_
y=[]
for i in soup.findAll('td', class_="table-body__cell u-center-text"):
    y.append(i.text)

# %%
y_=[]
for i in range (0,len(y),2):
    print(y[i])
    y_.append(y[i])

# %%
u=y_[0:9]
len(u)
v=[]
for j in range(1,len(y),2):
    print(y[j])
    v.append(y[j])

# %%
u_=y_[0:9]
len(u)
v_=v[0:9]
v_

# %%
m=soup.find('td',class_="rankings-block__banner--matches").text
m

# %%
n_=soup.find('td',class_="rankings-block__banner--points")
n_.text

# %%
l=u_.append(m)

# %%
o=v_.append(n_)

# %%
df=pd.DataFrame({'Matches':x_,'points':o,'Rank':l})
df

# %%
#b) Top 10 women’s ODI Batting players along with the records of their team and rating.

# %%
page=requests.get('https://www.icc-cricket.com/rankings/womens/player-rankings/odi')
page
soup=BeautifulSoup(page.content)
soup.text

# %%
x=[]
for i in soup.find_all('tr',class_="table-body"):
    x.append(i)

# %%
a=[]
for i in soup.find_all('td',class_="table-body__cell name"):
    a.append(i.text.replace('\n',''))

# %%
A=a[0:9]
A
a_=soup.find('div',class_="rankings-block__banner--name")
A_=a_.text
Aa=A.append(A_)

# %%
b=[]
for i in soup.find_all('span',class_="table-body__logo-text"):
    b.append(i.text)

# %%
B=b[0:10]
b_=soup.find('div',class_="rankings-block__banner--nationality")
B_=b_.text.replace('\n','').replace('892','')
Bb=B.append(B_)

# %%
c=[]
for i in soup.find_all('td',class_="table-body__cell u-text-right rating"):
    c.append(i.text)

# %%
C=c[0:10]
C
c_=soup.find('div',class_="rankings-block__banner--rating")
C_=b_.text.replace('\n','').replace('AUS','').replace('   ','')
C_
Cc=c.append(C_)

# %%
df=pd.DataFrame({'Player Name':[Aa],'Nationality':[Bb],'Rating':[Cc]})

# %%
df

# %%
#c) Top 10 women’s ODI all-rounder along with the records of their team and rating

# %%
page=requests.get('https://www.icc-cricket.com/rankings/womens/player-rankings/odi')
page
soup=BeautifulSoup(page.content)
soup

# %%
x=[]
for i in soup.find_all('tr',class_="table-body"):
    x.append(i)

# %%
a=[]
for i in soup.find_all('td',class_="table-body__cell name"):
    a.append(i.text.replace('\n',''))

# %%
A=a[18:28]

# %%
a_=[]
for i in  soup.findAll('div',class_='rankings-block__banner--name'):
    a_.append(i.text)

# %%
ac=a_[2]
ac

# %%
b=[]
for i in soup.find_all('span',class_="table-body__logo-text"):
    b.append(i.text)

# %%
B=b[18:28]

# %%
b_=[]
for i in soup.findAll('div',class_="rankings-block__banner--nationality"):
    b_.append(i.text.replace('\n','').replace('726',''))

# %%
bc=b_[2]
c=[]
for i in soup.find_all('td',class_="table-body__cell u-text-right rating"):
    c.append(i.text)

# %%
C=c[18:28]
C
c_=soup.find_all('div',class_="rankings-block__banner--rating")
C_=c_[2].text

# %% [markdown]
# # 7) Write a python program to scrape mentioned news details from https://www.cnbc.com/world/?region=world :

# %%
page=requests.get('https://www.cnbc.com/world/')
soup=BeautifulSoup(page.content)
soup
header=[]
for i in soup.find_all('div',class_="RiverPlusCard-cardLeft"):
    header.append(i.text)

# %%
header

# %%
links = []
for i in soup.findAll('div',{'class':'RiverHeadline-headline RiverHeadline-hasThumbnail'}):
    links.append(i.a['href'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6220/2164469543.py in <module>
#       1 links = []
# ----> 2 for i in soup.findAll('div',{'class':'RiverHeadline-headline RiverHeadline-hasThumbnail'}):
#       3     links.append(i.a['href'])
#
# NameError: name 'soup' is not defined

# %%
from datetime import date
today = date.today()
d = today.strftime("%m-%d-%y")

# %%
date=[]
for i in soup.find_all('span',class_="RiverByline-datePublished"):
    date.append(i.text)

# %%
date
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6220/1370450925.py in <module>
# ----> 1 date
#
# NameError: name 'date' is not defined

# %% [markdown]
# # 8) Write a python program to scrape the details of most downloaded articles from AI in last 90 days.

# %%
page=requests.get('https://www.journals.elsevier.com/artificial-intelligence/most-downloaded-articles')
soup=BeautifulSoup(page.content)
soup
Title=[]
for i in soup.find_all('h2',class_="sc-1qrq3sd-1 MKjKb sc-1nmom32-0 sc-1nmom32-1 hqhUYH ebTA-dR"):
    Title.append(i.text)

# %%
Title

# %%
Author=[]
for i in soup.find_all('span',class_="sc-1w3fpd7-0 pgLAT"):
    Author.append(i.text)

# %%
Year=[]
for i in soup.find_all('span',class_="sc-1thf9ly-2 bKddwo"):
    Year.append(i.text)

# %%
Links = []
for i in soup.findAll('a',class_='s-5smygv-0 nrDZj'):
    Links.append(i)

# %%
df=pd.DataFrame({'Title':Title,'Author Name':Author,'Year Of Publish':Year,'Links':Links})

# %%
df

# %% [markdown]
# # 9) Write a python program to scrape mentioned details from dineout.co.in :

# %%
page=requests.get('https://www.dineout.co.in/delhi-restaurants/buffet-special')
soup=BeautifulSoup(page.content)
soup

Name=[]
cusine=[]
for i in soup.find_all('div',class_="restnt-info cursor"):
    Name.append(i.text)

# %%
for i in soup.find_all('span',class_="double-line-ellipsis"):
    cusine.append(i.text)

# %%
loc=[]
for i in soup.find_all('div',class_="restnt-loc ellipsis"):
    loc.append(i.text)

# %%
rating=[]
for i in soup.find_all('div',class_="restnt-rating rating-4"):
    rating.append(i.text)

# %%
image=[]
for i in soup.find_all('img',class_="no-img"):
    image.append(i['data-src'])

# %%
df=pd.DataFrame({'Resturant Name':Name,'cusine':cusine,'location':loc,'Rating':rating,'Image URL':image})

# %%
df

# %% [markdown]
# # 10) Write a python program to scrape the details of top publications from Google Scholar from#

# %%
page=requests.get('https://scholar.google.com/citations?view_op=top_venues&hl=en')
soup=BeautifulSoup(page.content)
soup

# %%
rank=[]
for i in soup.find_all('td',class_="gsc_mvt_p"):
    rank.append(i.text.replace('.','').replace(',',''))

# %%
publication=[]
for i in soup.find_all('td',class_='gsc_mvt_t'):
    publication.append(i.text)

# %%
h5=[]
for i in soup.find_all('a',class_='gs_ibl gsc_mp_anchor'):
    h5.append(i.text)

# %%
h5_med=[]
for i in soup.find_all('span',class_="gs_ibl gsc_mp_anchor"):
    h5_med.append(i.text)

# %%
df=pd.DataFrame({'Rank':rank,'Publication':publication,'H5_Index':h5,'H5 Median':h5_med})
df
